# %%
# Cell 1: Verifikasi versi Python dan ketersediaan pustaka inti
import sys
print("Python version:", sys.version)

import pandas as pd 
import numpy as np

import matplotlib.pyplot as plt 
import seaborn as sns

print("Semua library siap digunakan.")
# Out:
# Python version: 3.14.6 | packaged by Anaconda, Inc. | (main, Jul  9 2026, 14:29:05) [MSC v.1942 64 bit (AMD64)]
# Semua library siap digunakan.

# %% [markdown]
# # Pertemuan 1 - Pengenalan Ekosistem ML & Eksplorasi Data
# ## Latihan Terbimbing
# **Nama:** Jaqckline Yesyuruniwati
# **NIM:** 224443056
# **Kelas:** 3AEC3

# %%
# Cell: Membuat dan mengoperasikan array NumPy
import numpy as np
arr = np.array([1, 2, 3, 4])
print(arr.mean()) # menghasilkan 2.5
print(arr * 2) # menghasilkan array([2, 4, 6, 8])
# Out:
# 2.5
# [2 4 6 8]

# %%
# Cell: Membangun DataFrame dari dictionary
import pandas as pd

data = {'Nama': ['Ali', 'Budi'], 'Nilai': [85, 90]}
df = pd.DataFrame(data)
print(df)
# Out:
#    Nama  Nilai
# 0   Ali     85
# 1  Budi     90

# %%
# Cell: Contoh dasar Matplotlib - plot garis
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y)
plt.title('Contoh Plot Garis')
plt.show()

# %%
# Cell: Contoh dasar Seaborn - scatter plot statistik
import seaborn as sns

sns.set_style('darkgrid')
tips = sns.load_dataset('tips') # dataset bawaan Seaborn

sns.scatterplot(data=tips, x='total_bill', y='tip')
plt.show()
